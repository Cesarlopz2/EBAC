# %%
#Importamos libreria pandas 
import pandas as pd

#Cragamos y visualizamos el archivo
df = pd.read_csv("C:\\Users\\cesar\\Downloads\\fifa_eda.csv")
df
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
# Mostrar las primeras 20 filas
rows_20 = df.head(20)
print("Primeras 20 filas: ")
rows_20
# Out:
# Primeras 20 filas:
#         ID               Name  Age Nationality  Overall  Potential  \
# 0   158023           L. Messi   31   Argentina       94         94
# 1    20801  Cristiano Ronaldo   33    Portugal       94         94
# 2   190871          Neymar Jr   26      Brazil       92         93
# 3   193080             De Gea   27       Spain       91         93
# 4   192985       K. De Bruyne   27     Belgium       91         92
# 5   183277          E. Hazard   27     Belgium       91         91
# 6   177003          L. Modrić   32     Croatia       91         91
# 7   176580          L. Suárez   31     Uruguay       91         91
# 8   155862       Sergio Ramos   32       Spain       91         91
# 9   200389           J. Oblak   25    Slovenia       90         93
# 10  188545     R. Lewandowski   29      Poland       90         90
# 11  182521           T. Kroos   28     Germany       90         90
# 12  182493           D. Godín   32     Uruguay       90         90
# ...

# %%
# Mostrar últimas 5 filas 
last_rows = df.tail(5)
print("Últimas 5 filas: ")
last_rows
# Out:
# Últimas 5 filas:
#            ID                Name  Age Nationality  Overall  Potential  \
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                    Club  Value  Wage Preferred Foot  International Reputation  \
# 18202   Crewe Alexandra   60.0   1.0          Right                       1.0
# 18203    Trelleborgs FF   60.0   1.0          Right                       1.0
# 18204  Cambridge United   60.0   1.0          Right                       1.0
# 18205   Tranmere Rovers   60.0   1.0          Right                       1.0
# 18206   Tranmere Rovers   60.0   1.0          Right                       1.0
#
# ...

# %%
# Mostrar Filas a aleatorias
sample_rows =df.sample(10)
print("Filas aleatorias: ")
sample_rows
# Out:
# Filas aleatorias:
#            ID          Name  Age Nationality  Overall  Potential  \
# 18001  242150   S. Laitinen   18     Finland       51         66
# 4102   219690    Diego Galo   34      Brazil       71         71
# 9222   245091  L. Ravanelli   21       Italy       66         75
# 5757   193057   C. Benschop   28     Curacao       69         69
# 13033  220663   M. Kallesøe   21     Denmark       63         73
# 9149   202322       N. Næss   25      Norway       66         69
# 15225  245220     A. Camara   20     Senegal       60         69
# 4326   211060       Elsinho   28      Brazil       71         71
# 15533  238449      A. Ikedi   19     Nigeria       59         72
# 8626   184288    D. Dervite   29      France       67         67
#
#                         Club   Value  Wage Preferred Foot  \
# 18001           HJK Helsinki    70.0   1.0          Right
# 4102                 CD Aves   725.0   8.0          Right
# ...

# %%
data_statistics = df.describe()
data_statistics
# Out:
#                   ID           Age       Overall     Potential          Value  \
# count   18207.000000  18207.000000  18207.000000  18207.000000   17955.000000
# mean   214298.338606     25.122206     66.238699     71.307299    2444.530214
# std     29965.244204      4.669943      6.908930      6.136496    5626.715434
# min        16.000000     16.000000     46.000000     48.000000      10.000000
# 25%    200315.500000     21.000000     62.000000     67.000000     325.000000
# 50%    221759.000000     25.000000     66.000000     71.000000     700.000000
# 75%    236529.500000     28.000000     71.000000     75.000000    2100.000000
# max    246620.000000     45.000000     94.000000     95.000000  118500.000000
#
#                Wage  International Reputation   Skill Moves        Joined  \
# count  18207.000000              18159.000000  18159.000000  18207.000000
# mean       9.731312                  1.113222      2.361308   2016.420607
# ...

# %%
print(df.dtypes)
# Out:
# ID                            int64
# Name                         object
# Age                           int64
# Nationality                  object
# Overall                       int64
# Potential                     int64
# Club                         object
# Value                       float64
# Wage                        float64
# Preferred Foot               object
# International Reputation    float64
# Skill Moves                 float64
# Position                     object
# Joined                        int64
# Contract Valid Until         object
# Height                      float64
# Weight                      float64
# Release Clause              float64
# dtype: object

# %%
# Creamos una nueva columna llamada "Years Playing"

# Importamos el modulo datetime para traer la fecha actual
from datetime import datetime

# Obtenemos la fecha actual.
año_actual = datetime.now().year

# Creamos la columna Years Playing
df['Years Playing'] = año_actual - df['Joined']

#Comprobamos el resultado
df['Years Playing']
# Out:
# 0        20
# 1         6
# 2         7
# 3        13
# 4         9
#          ..
# 18202     7
# 18203     6
# 18204     7
# 18205     6
# 18206     6
# Name: Years Playing, Length: 18207, dtype: int64

# %%
# Buscar y mostrar a todos los jugadores de Mexico

jugadores_mexicanos = df[df['Nationality'] == 'Mexico']
jugadores_mexicanos
# Out:
#            ID          Name  Age Nationality  Overall  Potential  \
# 306    171897   A. Guardado   31      Mexico       82         82
# 329    221992     H. Lozano   22      Mexico       81         86
# 371    193165     J. Corona   25      Mexico       81         83
# 397    169416       C. Vela   29      Mexico       81         81
# 406    156519    H. Herrera   28      Mexico       81         81
# ...       ...           ...  ...         ...      ...        ...
# 17373  244828  R. Gutiérrez   22      Mexico       54         64
# 17614  239739      A. Ocejo   20      Mexico       53         62
# 18037  246089      C. Landa   19      Mexico       50         60
# 18068  240286     J. García   20      Mexico       50         62
# 18113  237045    R. Pasquel   22      Mexico       50         60
#
#                               Club    Value  Wage Preferred Foot  \
# 306                     Real Betis  19000.0  35.0           Left
# ...

# %%
# Ordenar y mostrar los datos por la columna ReleaseClause (sueldo)
df_releaseclause = df.sort_values(by='Release Clause', ascending=False) #Indicamos que lo queremos en orden descendente
df_releaseclause
# Out:
#            ID              Name  Age Nationality  Overall  Potential  \
# 2      190871         Neymar Jr   26      Brazil       92         93
# 0      158023          L. Messi   31   Argentina       94         94
# 4      192985      K. De Bruyne   27     Belgium       91         92
# 5      183277         E. Hazard   27     Belgium       91         91
# 25     231747         K. Mbappé   19      France       88         95
# ...       ...               ...  ...         ...      ...        ...
# 16204  176860        C. Månsson   37      Sweden       58         58
# 16249  176631       B. Lekström   37      Sweden       58         58
# 16565  232893       K. Kitamoto   36       Japan       57         57
# 16628  102881  K. Stamatopoulos   38      Canada       57         57
# 17209  237751        Y. Nishibe   37       Japan       55         55
#
#                       Club     Value   Wage Preferred Foot  \
# 2      Paris Saint-Germain  118500.0  290.0          Right
# ...

# %%
# Generar un nuevo dataset que contenga el año (joined) y el número de jugadores (groupby)
players_by_year = df.groupby('Joined').size().reset_index(name='NumberOfPlayers')
players_by_year
# Out:
#     Joined  NumberOfPlayers
# 0     1991                1
# 1     1998                3
# 2     1999                1
# 3     2000                2
# 4     2001                2
# 5     2002               10
# 6     2003               13
# 7     2004               12
# 8     2005               17
# 9     2006               18
# 10    2007               38
# 11    2008               53
# 12    2009               78
# 13    2010              131
# 14    2011              201
# 15    2012              340
# 16    2013              458
# 17    2014              818
# 18    2015             1336
# 19    2016             3799
# 20    2017             4307
# 21    2018             6569

# %%
# Crear Grafico
import seaborn as sns
import matplotlib.pyplot as plt

# Creamos el grafico con la libreria Seaborn
plt.figure(figsize=(12, 6))
sns.barplot(data=players_by_year, x='Joined', y='NumberOfPlayers', palette='viridis')

# Personalizar el gráfico con matplotlib.pyplot
plt.title('Número de Jugadores por Año')
plt.xlabel('Año')
plt.ylabel('Número de Jugadores')
plt.xticks(rotation=45)
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()
